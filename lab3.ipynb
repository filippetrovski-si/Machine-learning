# %%
import pandas as pd
data=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Data_Cortex_Nuclear.xls')
data.head(10)
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Genotype  Treatment  Behavior   class
# 0   309_1  0.503644  0.747193  0.430175  ...   Control  Memantine       C/S  c-CS-m
# 1   309_2  0.514617  0.689064  0.411770  ...   Control  Memantine       C/S  c-CS-m
# 2   309_3  0.509183  0.730247  0.418309  ...   Control  Memantine       C/S  c-CS-m
# 3   309_4  0.442107  0.617076  0.358626  ...   Control  Memantine       C/S  c-CS-m
# 4   309_5  0.434940  0.617430  0.358802  ...   Control  Memantine       C/S  c-CS-m
# 5   309_6  0.447506  0.628176  0.367388  ...   Control  Memantine       C/S  c-CS-m
# 6   309_7  0.428033  0.573696  0.342709  ...   Control  Memantine       C/S  c-CS-m
# 7   309_8  0.416923  0.564036  0.327703  ...   Control  Memantine       C/S  c-CS-m
# 8   309_9  0.386311  0.538428  0.317720  ...   Control  Memantine       C/S  c-CS-m
# 9  309_10  0.380827  0.499294  0.362462  ...   Control  Memantine       C/S  c-CS-m
#
# [10 rows x 82 columns]

# %%
#trganje na prviot i poslednite 4 atributi od podatocnoto mnozestvo
datanew=data.drop(['MouseID','Genotype','Treatment','Behavior','class'],axis=1)
datanew
# Out:
#       DYRK1A_N   ITSN1_N    BDNF_N  ...    EGR1_N  H3MeK4_N    CaNA_N
# 0     0.503644  0.747193  0.430175  ...  0.131790  0.128186  1.675652
# 1     0.514617  0.689064  0.411770  ...  0.135103  0.131119  1.743610
# 2     0.509183  0.730247  0.418309  ...  0.133362  0.127431  1.926427
# 3     0.442107  0.617076  0.358626  ...  0.147444  0.146901  1.700563
# 4     0.434940  0.617430  0.358802  ...  0.140314  0.148380  1.839730
# ...        ...       ...       ...  ...       ...       ...       ...
# 1075  0.254860  0.463591  0.254860  ...  0.204660  0.328327  1.364823
# 1076  0.272198  0.474163  0.251638  ...  0.200415  0.293435  1.364478
# 1077  0.228700  0.395179  0.234118  ...  0.229193  0.355213  1.430825
# 1078  0.221242  0.412894  0.243974  ...  0.251317  0.365353  1.404031
# 1079  0.302626  0.461059  0.256564  ...  0.252995  0.365278  1.370999
#
# [1080 rows x 77 columns]

# %%
#spravuvanje so missing values
mean= datanew.mean(axis=0)
datanew.isnull().sum()
modified_v1 = []   
modified_v1 = datanew.apply(lambda v1 : v1.fillna(v1.mean()),axis=0)
from sklearn.preprocessing import StandardScaler
modified_v1 = StandardScaler().fit_transform(modified_v1)

# %%
#pca-2 dimenzii
from sklearn.decomposition import PCA 
pca = PCA(n_components=2)
pca.fit(modified_v1)
pca_dataset = pca.transform(modified_v1)

# %%
#vizualizacija na pca so 2 dimenzii
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,9))
sns.scatterplot(x=pca_dataset[:, 0], y=pca_dataset[:, 1])
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
#obid preku k-means da se doznae optimalniot broj na klasteri preku vizuelizacija
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
mms = MinMaxScaler()
mms.fit(modified_v1)
data_transformed = mms.transform(modified_v1)
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.mixture import GaussianMixture
#2 dimenzii na tsne
TSNE_data = TSNE(n_components=2).fit_transform(modified_v1)

# %%
# 2 i 3 baranje se ispolnuvaat so ovaj kod
#vizuelizacija na rezultatite od klasteriranjeto
fig, axs = plt.subplots(2,4,figsize=(18,11))
x=0
y=0

for clusters in range(2,10):
  #GaussianMixture metod na klasteriranje
  gmm = GaussianMixture(n_components=clusters, random_state=0)
  gmm.fit(TSNE_data)
  labels1 = gmm.predict(TSNE_data)
  axs[x,y].scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=labels1, s=40, cmap='inferno', zorder=2);
  axs[x,y].set_title("Broj na klasteri: {}".format(clusters))
  if y == 3:
    y=0
    x=x+1
  else:
    y=y+1

# %%
# 2 i 3 baranje se ispolnuvaat so ovaj kod
#vizuelizacija na AgglomerativeClustering
fig, axs = plt.subplots(2,4,figsize=(18,11))
x=0
y=0
for clusters in range(2,10):
  #AgglomerativeClustering metod na klasteriranje
  agg = AgglomerativeClustering(n_clusters=clusters)
  labels2 = agg.fit_predict(TSNE_data)
  axs[x,y].scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=labels2, s=40, cmap='inferno', zorder=2);
  axs[x,y].set_title("Broj na klasteri: {}".format(clusters))
  if y == 3:
    y=0
    x=x+1
  else:
    y=y+1

# %%
# 2 i 3 baranje se ispolnuvaat so ovaj kod
#vizuelizacija na k-means
fig, axs = plt.subplots(2,4,figsize=(18,11))
x=0
y=0
for clusters in range(2,10):
  #k-means klasteriranje
  km = KMeans(n_clusters=clusters,  random_state=0)
  km.fit(TSNE_data)
  labels3 = km.predict(TSNE_data)
  axs[x,y].scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=labels3, s=40, cmap='inferno', zorder=2);
  axs[x,y].set_title("Broj na klasteri: {}".format(clusters))
  if y == 3:
    y=0
    x=x+1
  else:
    y=y+1
